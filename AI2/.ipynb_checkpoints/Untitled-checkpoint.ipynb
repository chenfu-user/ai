# %%
import time
import torch
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

from torch import nn, optim
import torch.nn.functional as F
import torchvision
import os,json
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torchvision import models
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(torch.__version__)
print(torchvision.__version__)
print(device)
# Out:
# 1.7.1+cu110
# 0.8.2+cu110
# cuda:0

# %%
Batch = 16

# %%
class MyDataset(Dataset):
    def __init__(self, transform=None):
        self.transform = transforms.Compose([
        transforms.Grayscale(num_output_channels=1), # 彩色图像转灰度图像num_output_channels默认1
        transforms.ToTensor()
    ])

        
        self.images = []
        self.labels = []
        self.transform = transform
        for i in range(6147):
            self.images.append( 'img/'+  str(i) + '.jpg')
            file = open( 'label/'+  str(i) + '.json','r')
            a = json.load(file)
            l = [a['x'],a['z']]
#             l = [a['z']]
            l = torch.Tensor(l)
            self.labels.append(l)
            
            file.close()
 
    def __len__(self):
        # 返回数据集的数据数量
        return len(self.images)
 
    def __getitem__(self, index):
        img_path = self.images[index]
        label = self.labels[index]
        label = torch.unsqueeze(label, dim=0)  
        img0 = cv2.imread(img_path)
        img = cv2.cvtColor(img0[155: :], cv2.COLOR_BGR2RGB)
        #img = torch.Tensor(img)
        #img = torch.unsqueeze(img, dim=0)
        img = torch.from_numpy(img).permute(2, 0, 1)/255
#         img = Image.fromarray(img)
#         img = transform(img)
        
        sample = {'image': img, 'label': label}
        if self.transform:
            sample['image'] = self.transform(sample['image'])
        return sample
    
img0 = cv2.imread('img/1111.jpg')
img = cv2.cvtColor(img0[155: :], cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
train_dataset = MyDataset()
dataloader = DataLoader(train_dataset, batch_size=Batch, shuffle=True)
for index, batch_data in enumerate(dataloader):
        print(index, batch_data['image'].shape, batch_data['label'].shape)

# %%
net = models.alexnet()

net.classifier[6] = nn.Linear(4096,2)
print(net)

#print(net.conv1)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %%
def train(model, train_batch, batch_size, optimizer, device, num_epochs):
    model = model.to(device)
    print("run in " , device)
 
    # 损失函数,MSE函数
    loss = torch.nn.MSELoss()
 
    for epoch in range(num_epochs):
        train_loss_sum, train_rmse_sum, n, batch_count = 0.0, 0.0, 0, 0
        start = time.time()
 
        for X, y in enumerate(train_batch):
            # 转置
            X = y['image']
            y = y['label']
            X = X.to(device)
#             print(X.size(),y.size())
            y = y.to(device)
 
 
            # 前向计算
            y_pre = model(X)
            y = torch.sum(y,dim=1)
#             print(y_pre.size())
#             print(y.size())
 
            l = loss(y_pre, y)
 
            # 梯度清零
            optimizer.zero_grad()
 
            l.backward()
            optimizer.step()
 
            train_loss_sum += l.cpu().item()
            train_rmse_sum += torch.sqrt(((y_pre-y)**2).sum()).cpu().item()
            n += y.shape[0]
            batch_count += 1
 
        print("epoch:%d, loss:%.4f, train_rmse:%.3f,  cost: %.1f sec" %
              (epoch + 1, train_loss_sum / batch_count, train_rmse_sum / n, time.time() - start))

# %%
lr = 0.0002

optimizer = torch.optim.Adam(net.parameters(),lr = lr)
num_epochs = 300
train(net, dataloader, Batch, optimizer, device, num_epochs)
# Out:
# run in  cuda:0
# epoch:1, loss:0.0487, train_rmse:0.064,  cost: 54.1 sec
# epoch:2, loss:0.0083, train_rmse:0.031,  cost: 50.8 sec
# epoch:3, loss:0.0063, train_rmse:0.027,  cost: 51.1 sec
# epoch:4, loss:0.0062, train_rmse:0.027,  cost: 51.4 sec
# epoch:5, loss:0.0049, train_rmse:0.024,  cost: 51.6 sec
# epoch:6, loss:0.0048, train_rmse:0.023,  cost: 52.1 sec
# epoch:7, loss:0.0044, train_rmse:0.022,  cost: 52.5 sec
# epoch:8, loss:0.0036, train_rmse:0.020,  cost: 52.5 sec
# epoch:9, loss:0.0035, train_rmse:0.020,  cost: 52.8 sec
# epoch:10, loss:0.0035, train_rmse:0.020,  cost: 52.8 sec
# epoch:11, loss:0.0031, train_rmse:0.019,  cost: 53.1 sec
# epoch:12, loss:0.0029, train_rmse:0.018,  cost: 53.0 sec
# epoch:13, loss:0.0028, train_rmse:0.018,  cost: 53.1 sec
# epoch:14, loss:0.0026, train_rmse:0.017,  cost: 53.4 sec
# epoch:15, loss:0.0026, train_rmse:0.017,  cost: 53.3 sec
# epoch:16, loss:0.0023, train_rmse:0.016,  cost: 53.5 sec
# epoch:17, loss:0.0021, train_rmse:0.016,  cost: 53.0 sec
# epoch:18, loss:0.0022, train_rmse:0.016,  cost: 53.1 sec
# epoch:19, loss:0.0022, train_rmse:0.016,  cost: 53.2 sec
# epoch:20, loss:0.0022, train_rmse:0.016,  cost: 53.1 sec
# epoch:21, loss:0.0020, train_rmse:0.015,  cost: 53.3 sec
# epoch:22, loss:0.0020, train_rmse:0.015,  cost: 53.4 sec
# epoch:23, loss:0.0020, train_rmse:0.015,  cost: 53.5 sec
# epoch:24, loss:0.0019, train_rmse:0.015,  cost: 53.4 sec
# epoch:25, loss:0.0019, train_rmse:0.015,  cost: 53.0 sec
# epoch:26, loss:0.0019, train_rmse:0.015,  cost: 53.5 sec
# epoch:27, loss:0.0017, train_rmse:0.014,  cost: 53.6 sec
# epoch:28, loss:0.0016, train_rmse:0.013,  cost: 53.3 sec
# epoch:29, loss:0.0017, train_rmse:0.014,  cost: 53.4 sec
# epoch:30, loss:0.0017, train_rmse:0.014,  cost: 53.4 sec
# epoch:31, loss:0.0016, train_rmse:0.013,  cost: 53.5 sec
# epoch:32, loss:0.0015, train_rmse:0.013,  cost: 53.2 sec
# epoch:33, loss:0.0015, train_rmse:0.013,  cost: 53.6 sec
# epoch:34, loss:0.0015, train_rmse:0.013,  cost: 53.4 sec
# epoch:35, loss:0.0014, train_rmse:0.013,  cost: 53.7 sec
# epoch:36, loss:0.0016, train_rmse:0.013,  cost: 53.5 sec
# epoch:37, loss:0.0014, train_rmse:0.012,  cost: 53.5 sec
# epoch:38, loss:0.0014, train_rmse:0.012,  cost: 54.7 sec
# epoch:39, loss:0.0016, train_rmse:0.014,  cost: 55.5 sec
# epoch:40, loss:0.0014, train_rmse:0.012,  cost: 54.3 sec
# epoch:41, loss:0.0013, train_rmse:0.012,  cost: 54.5 sec
# epoch:42, loss:0.0013, train_rmse:0.012,  cost: 54.3 sec
# epoch:43, loss:0.0014, train_rmse:0.012,  cost: 54.2 sec
# epoch:44, loss:0.0011, train_rmse:0.011,  cost: 54.3 sec
# epoch:45, loss:0.0013, train_rmse:0.012,  cost: 53.9 sec
# epoch:46, loss:0.0012, train_rmse:0.012,  cost: 53.9 sec
# epoch:47, loss:0.0012, train_rmse:0.012,  cost: 53.9 sec
# epoch:48, loss:0.0012, train_rmse:0.012,  cost: 53.9 sec
# epoch:49, loss:0.0011, train_rmse:0.011,  cost: 53.9 sec
# epoch:50, loss:0.0012, train_rmse:0.011,  cost: 53.7 sec
# epoch:51, loss:0.0011, train_rmse:0.011,  cost: 53.9 sec
# epoch:52, loss:0.0012, train_rmse:0.012,  cost: 53.9 sec
# epoch:53, loss:0.0011, train_rmse:0.011,  cost: 53.9 sec
# epoch:54, loss:0.0011, train_rmse:0.011,  cost: 53.9 sec
# epoch:55, loss:0.0010, train_rmse:0.011,  cost: 54.2 sec
# epoch:56, loss:0.0010, train_rmse:0.011,  cost: 53.9 sec
# epoch:57, loss:0.0010, train_rmse:0.011,  cost: 54.0 sec
# epoch:58, loss:0.0011, train_rmse:0.011,  cost: 54.3 sec
# epoch:59, loss:0.0010, train_rmse:0.011,  cost: 54.4 sec
# epoch:60, loss:0.0010, train_rmse:0.011,  cost: 54.1 sec
# epoch:61, loss:0.0009, train_rmse:0.010,  cost: 54.2 sec
# epoch:62, loss:0.0010, train_rmse:0.011,  cost: 54.3 sec
# epoch:63, loss:0.0009, train_rmse:0.010,  cost: 54.2 sec
# epoch:64, loss:0.0010, train_rmse:0.010,  cost: 54.0 sec
# epoch:65, loss:0.0009, train_rmse:0.010,  cost: 54.2 sec
# epoch:66, loss:0.0009, train_rmse:0.010,  cost: 54.6 sec
# epoch:67, loss:0.0009, train_rmse:0.010,  cost: 54.0 sec
# epoch:68, loss:0.0009, train_rmse:0.010,  cost: 54.1 sec
# epoch:69, loss:0.0008, train_rmse:0.010,  cost: 54.1 sec
# epoch:70, loss:0.0009, train_rmse:0.010,  cost: 54.1 sec
# epoch:71, loss:0.0008, train_rmse:0.010,  cost: 54.0 sec
# epoch:72, loss:0.0008, train_rmse:0.010,  cost: 53.9 sec
# epoch:73, loss:0.0008, train_rmse:0.010,  cost: 54.1 sec
# epoch:74, loss:0.0008, train_rmse:0.009,  cost: 54.0 sec
# epoch:75, loss:0.0007, train_rmse:0.009,  cost: 54.0 sec
# epoch:76, loss:0.0008, train_rmse:0.009,  cost: 54.0 sec
# epoch:77, loss:0.0008, train_rmse:0.009,  cost: 53.9 sec
# epoch:78, loss:0.0008, train_rmse:0.009,  cost: 54.1 sec
# epoch:79, loss:0.0008, train_rmse:0.009,  cost: 54.1 sec
# epoch:80, loss:0.0008, train_rmse:0.009,  cost: 54.2 sec
# epoch:81, loss:0.0007, train_rmse:0.009,  cost: 54.2 sec
# epoch:82, loss:0.0007, train_rmse:0.009,  cost: 54.2 sec
# epoch:83, loss:0.0007, train_rmse:0.009,  cost: 54.2 sec
# epoch:84, loss:0.0007, train_rmse:0.009,  cost: 54.1 sec
# epoch:85, loss:0.0007, train_rmse:0.009,  cost: 54.3 sec
# epoch:86, loss:0.0008, train_rmse:0.009,  cost: 54.3 sec
# epoch:87, loss:0.0007, train_rmse:0.009,  cost: 54.8 sec
# epoch:88, loss:0.0007, train_rmse:0.009,  cost: 54.2 sec
# epoch:89, loss:0.0006, train_rmse:0.008,  cost: 54.5 sec
# epoch:90, loss:0.0007, train_rmse:0.009,  cost: 54.4 sec
# epoch:91, loss:0.0007, train_rmse:0.009,  cost: 54.5 sec
# epoch:92, loss:0.0007, train_rmse:0.009,  cost: 54.3 sec
# epoch:93, loss:0.0007, train_rmse:0.009,  cost: 54.5 sec
# epoch:94, loss:0.0007, train_rmse:0.008,  cost: 54.4 sec
# epoch:95, loss:0.0006, train_rmse:0.008,  cost: 54.3 sec
# epoch:96, loss:0.0006, train_rmse:0.008,  cost: 54.2 sec
# epoch:97, loss:0.0006, train_rmse:0.008,  cost: 54.3 sec
# epoch:98, loss:0.0006, train_rmse:0.008,  cost: 54.2 sec
# epoch:99, loss:0.0005, train_rmse:0.008,  cost: 54.1 sec
# epoch:100, loss:0.0006, train_rmse:0.008,  cost: 54.2 sec
# epoch:101, loss:0.0006, train_rmse:0.008,  cost: 54.3 sec
# epoch:102, loss:0.0006, train_rmse:0.008,  cost: 54.2 sec
# epoch:103, loss:0.0006, train_rmse:0.008,  cost: 54.1 sec
# epoch:104, loss:0.0006, train_rmse:0.008,  cost: 54.1 sec
# epoch:105, loss:0.0006, train_rmse:0.008,  cost: 54.3 sec
# epoch:106, loss:0.0006, train_rmse:0.008,  cost: 54.6 sec
# epoch:107, loss:0.0005, train_rmse:0.008,  cost: 54.2 sec
# epoch:108, loss:0.0005, train_rmse:0.008,  cost: 54.3 sec
# epoch:109, loss:0.0006, train_rmse:0.008,  cost: 54.4 sec
# epoch:110, loss:0.0005, train_rmse:0.008,  cost: 54.1 sec
# epoch:111, loss:0.0005, train_rmse:0.008,  cost: 54.1 sec
# epoch:112, loss:0.0005, train_rmse:0.008,  cost: 54.2 sec
# epoch:113, loss:0.0005, train_rmse:0.008,  cost: 54.3 sec
# epoch:114, loss:0.0005, train_rmse:0.008,  cost: 54.3 sec
# epoch:115, loss:0.0006, train_rmse:0.008,  cost: 54.1 sec
# epoch:116, loss:0.0006, train_rmse:0.008,  cost: 54.2 sec
# epoch:117, loss:0.0005, train_rmse:0.008,  cost: 54.3 sec
# epoch:118, loss:0.0005, train_rmse:0.008,  cost: 54.2 sec
# epoch:119, loss:0.0005, train_rmse:0.007,  cost: 54.0 sec
# epoch:120, loss:0.0006, train_rmse:0.008,  cost: 54.2 sec
# epoch:121, loss:0.0005, train_rmse:0.007,  cost: 54.3 sec
# epoch:122, loss:0.0005, train_rmse:0.007,  cost: 54.2 sec
# epoch:123, loss:0.0005, train_rmse:0.008,  cost: 54.2 sec
# epoch:124, loss:0.0005, train_rmse:0.008,  cost: 54.1 sec
# epoch:125, loss:0.0005, train_rmse:0.007,  cost: 54.2 sec
# epoch:126, loss:0.0005, train_rmse:0.008,  cost: 54.2 sec
# epoch:127, loss:0.0005, train_rmse:0.007,  cost: 54.1 sec
# epoch:128, loss:0.0005, train_rmse:0.007,  cost: 54.3 sec
# epoch:129, loss:0.0005, train_rmse:0.007,  cost: 54.0 sec
# epoch:130, loss:0.0005, train_rmse:0.008,  cost: 54.1 sec
# epoch:131, loss:0.0005, train_rmse:0.007,  cost: 54.1 sec
# epoch:132, loss:0.0005, train_rmse:0.007,  cost: 54.3 sec
# epoch:133, loss:0.0004, train_rmse:0.007,  cost: 54.4 sec
# epoch:134, loss:0.0005, train_rmse:0.007,  cost: 54.4 sec
# epoch:135, loss:0.0005, train_rmse:0.007,  cost: 54.1 sec
# epoch:136, loss:0.0005, train_rmse:0.007,  cost: 54.2 sec
# epoch:137, loss:0.0005, train_rmse:0.007,  cost: 54.3 sec
# epoch:138, loss:0.0005, train_rmse:0.007,  cost: 54.3 sec
# epoch:139, loss:0.0004, train_rmse:0.007,  cost: 54.4 sec
# epoch:140, loss:0.0005, train_rmse:0.007,  cost: 54.2 sec
# epoch:141, loss:0.0004, train_rmse:0.007,  cost: 54.3 sec
# epoch:142, loss:0.0005, train_rmse:0.007,  cost: 54.3 sec
# epoch:143, loss:0.0004, train_rmse:0.007,  cost: 54.2 sec
# epoch:144, loss:0.0005, train_rmse:0.007,  cost: 54.2 sec
# epoch:145, loss:0.0005, train_rmse:0.007,  cost: 54.1 sec
# epoch:146, loss:0.0005, train_rmse:0.007,  cost: 54.0 sec
# epoch:147, loss:0.0005, train_rmse:0.007,  cost: 54.2 sec
# epoch:148, loss:0.0004, train_rmse:0.007,  cost: 54.1 sec
# epoch:149, loss:0.0004, train_rmse:0.007,  cost: 54.1 sec
# epoch:150, loss:0.0004, train_rmse:0.007,  cost: 54.2 sec
# epoch:151, loss:0.0004, train_rmse:0.007,  cost: 54.2 sec
# epoch:152, loss:0.0004, train_rmse:0.007,  cost: 54.3 sec
# epoch:153, loss:0.0004, train_rmse:0.007,  cost: 54.1 sec
# epoch:154, loss:0.0004, train_rmse:0.007,  cost: 54.2 sec
# epoch:155, loss:0.0004, train_rmse:0.007,  cost: 54.1 sec
# epoch:156, loss:0.0004, train_rmse:0.007,  cost: 54.2 sec
# epoch:157, loss:0.0004, train_rmse:0.007,  cost: 54.2 sec
# epoch:158, loss:0.0005, train_rmse:0.007,  cost: 54.3 sec
# epoch:159, loss:0.0004, train_rmse:0.007,  cost: 54.1 sec
# epoch:160, loss:0.0004, train_rmse:0.007,  cost: 54.2 sec
# epoch:161, loss:0.0004, train_rmse:0.007,  cost: 54.4 sec
# epoch:162, loss:0.0004, train_rmse:0.006,  cost: 54.4 sec
# epoch:163, loss:0.0004, train_rmse:0.007,  cost: 54.3 sec
# epoch:164, loss:0.0004, train_rmse:0.007,  cost: 54.4 sec
# epoch:165, loss:0.0004, train_rmse:0.007,  cost: 54.4 sec
# epoch:166, loss:0.0004, train_rmse:0.006,  cost: 54.3 sec
# epoch:167, loss:0.0004, train_rmse:0.006,  cost: 54.3 sec
# epoch:168, loss:0.0004, train_rmse:0.006,  cost: 54.5 sec
# epoch:169, loss:0.0004, train_rmse:0.006,  cost: 54.4 sec
# epoch:170, loss:0.0005, train_rmse:0.007,  cost: 54.5 sec
# epoch:171, loss:0.0005, train_rmse:0.007,  cost: 54.4 sec
# epoch:172, loss:0.0005, train_rmse:0.007,  cost: 54.8 sec
# epoch:173, loss:0.0004, train_rmse:0.006,  cost: 54.5 sec
# epoch:174, loss:0.0004, train_rmse:0.006,  cost: 54.4 sec
# epoch:175, loss:0.0004, train_rmse:0.006,  cost: 54.5 sec
# epoch:176, loss:0.0004, train_rmse:0.007,  cost: 54.4 sec
# epoch:177, loss:0.0004, train_rmse:0.006,  cost: 54.4 sec
# epoch:178, loss:0.0004, train_rmse:0.006,  cost: 54.5 sec
# epoch:179, loss:0.0004, train_rmse:0.007,  cost: 54.5 sec
# epoch:180, loss:0.0004, train_rmse:0.006,  cost: 54.4 sec
# epoch:181, loss:0.0004, train_rmse:0.006,  cost: 54.6 sec
# epoch:182, loss:0.0004, train_rmse:0.006,  cost: 54.4 sec
# epoch:183, loss:0.0004, train_rmse:0.006,  cost: 54.4 sec
# epoch:184, loss:0.0004, train_rmse:0.006,  cost: 54.7 sec
# epoch:185, loss:0.0004, train_rmse:0.006,  cost: 54.7 sec
# epoch:186, loss:0.0004, train_rmse:0.006,  cost: 54.6 sec
# epoch:187, loss:0.0004, train_rmse:0.006,  cost: 54.8 sec
# epoch:188, loss:0.0004, train_rmse:0.006,  cost: 54.6 sec
# epoch:189, loss:0.0004, train_rmse:0.006,  cost: 54.6 sec
# epoch:190, loss:0.0004, train_rmse:0.006,  cost: 54.7 sec
# epoch:191, loss:0.0004, train_rmse:0.007,  cost: 54.5 sec
# epoch:192, loss:0.0004, train_rmse:0.006,  cost: 54.6 sec
# epoch:193, loss:0.0004, train_rmse:0.006,  cost: 54.6 sec
# epoch:194, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:195, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:196, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:197, loss:0.0004, train_rmse:0.006,  cost: 54.6 sec
# epoch:198, loss:0.0004, train_rmse:0.006,  cost: 54.7 sec
# epoch:199, loss:0.0004, train_rmse:0.006,  cost: 54.7 sec
# epoch:200, loss:0.0004, train_rmse:0.006,  cost: 54.9 sec
# epoch:201, loss:0.0004, train_rmse:0.007,  cost: 54.9 sec
# epoch:202, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:203, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:204, loss:0.0003, train_rmse:0.006,  cost: 55.1 sec
# epoch:205, loss:0.0004, train_rmse:0.006,  cost: 55.0 sec
# epoch:206, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:207, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:208, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:209, loss:0.0004, train_rmse:0.006,  cost: 54.8 sec
# epoch:210, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:211, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:212, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:213, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:214, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:215, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:216, loss:0.0003, train_rmse:0.006,  cost: 55.0 sec
# epoch:217, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:218, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:219, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:220, loss:0.0004, train_rmse:0.006,  cost: 54.7 sec
# epoch:221, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:222, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:223, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:224, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:225, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:226, loss:0.0003, train_rmse:0.006,  cost: 54.9 sec
# epoch:227, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:228, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:229, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:230, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:231, loss:0.0004, train_rmse:0.006,  cost: 54.9 sec
# epoch:232, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:233, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:234, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:235, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:236, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:237, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:238, loss:0.0003, train_rmse:0.006,  cost: 54.8 sec
# epoch:239, loss:0.0003, train_rmse:0.006,  cost: 54.3 sec
# epoch:240, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:241, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:242, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:243, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:244, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:245, loss:0.0003, train_rmse:0.005,  cost: 54.4 sec
# epoch:246, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:247, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:248, loss:0.0003, train_rmse:0.005,  cost: 54.6 sec
# epoch:249, loss:0.0003, train_rmse:0.005,  cost: 54.7 sec
# epoch:250, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:251, loss:0.0003, train_rmse:0.006,  cost: 54.4 sec
# epoch:252, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:253, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:254, loss:0.0003, train_rmse:0.005,  cost: 54.7 sec
# epoch:255, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:256, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:257, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:258, loss:0.0003, train_rmse:0.006,  cost: 54.4 sec
# epoch:259, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:260, loss:0.0003, train_rmse:0.005,  cost: 54.7 sec
# epoch:261, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:262, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:263, loss:0.0003, train_rmse:0.005,  cost: 54.7 sec
# epoch:264, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:265, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:266, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:267, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:268, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:269, loss:0.0003, train_rmse:0.005,  cost: 54.6 sec
# epoch:270, loss:0.0003, train_rmse:0.005,  cost: 54.6 sec
# epoch:271, loss:0.0003, train_rmse:0.005,  cost: 54.6 sec
# epoch:272, loss:0.0003, train_rmse:0.006,  cost: 54.6 sec
# epoch:273, loss:0.0003, train_rmse:0.005,  cost: 54.7 sec
# epoch:274, loss:0.0003, train_rmse:0.005,  cost: 54.4 sec
# epoch:275, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:276, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:277, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:278, loss:0.0003, train_rmse:0.006,  cost: 54.7 sec
# epoch:279, loss:0.0003, train_rmse:0.005,  cost: 54.4 sec
# epoch:280, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:281, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:282, loss:0.0003, train_rmse:0.005,  cost: 54.7 sec
# epoch:283, loss:0.0003, train_rmse:0.005,  cost: 54.6 sec
# epoch:284, loss:0.0003, train_rmse:0.005,  cost: 54.6 sec
# epoch:285, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:286, loss:0.0002, train_rmse:0.005,  cost: 54.4 sec
# epoch:287, loss:0.0003, train_rmse:0.005,  cost: 54.7 sec
# epoch:288, loss:0.0002, train_rmse:0.005,  cost: 54.6 sec
# epoch:289, loss:0.0003, train_rmse:0.005,  cost: 54.7 sec
# epoch:290, loss:0.0002, train_rmse:0.005,  cost: 54.5 sec
# epoch:291, loss:0.0003, train_rmse:0.005,  cost: 54.5 sec
# epoch:292, loss:0.0003, train_rmse:0.006,  cost: 54.5 sec
# epoch:293, loss:0.0002, train_rmse:0.005,  cost: 54.4 sec
# epoch:294, loss:0.0003, train_rmse:0.005,  cost: 54.0 sec
# epoch:295, loss:0.0003, train_rmse:0.005,  cost: 54.0 sec
# epoch:296, loss:0.0003, train_rmse:0.005,  cost: 53.9 sec
# epoch:297, loss:0.0003, train_rmse:0.006,  cost: 54.1 sec
# epoch:298, loss:0.0003, train_rmse:0.005,  cost: 54.3 sec
# epoch:299, loss:0.0003, train_rmse:0.005,  cost: 54.2 sec
# epoch:300, loss:0.0002, train_rmse:0.005,  cost: 54.1 sec

# %%
#train(net, dataloader, Batch, optimizer, device, 50)

# %%
#train(net, dataloader, Batch, optimizer, device, 150)

# %%
save_path = 'twouse.pt'
torch.save(net.state_dict(), save_path)

# %%
net.eval()
def pre(model, img_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img[155: :], cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    img = torch.from_numpy(img).permute(2, 0, 1)/255
    img = torch.Tensor(img)
    img = torch.unsqueeze(img, dim=0)  
    
    img = img.to(device)
    output = model(img)
    #output = torch.sum(output,dim=1)
    
    #_, predicted = torch.max(output, 1)
    return output
print(pre(net,'img/1999.jpg'))
# Out:
# tensor([[ 5.9910e-01, -5.2252e-04]], device='cuda:0', grad_fn=<AddmmBackward>)

# %%
model = models.alexnet()

model.classifier[6] = nn.Linear(4096,2)

model.load_state_dict(torch.load(save_path))
model.eval()
model = model.to(device)

# %%
def predict(model, img_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img[155: :], cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    img = torch.from_numpy(img).permute(2, 0, 1)/255
    img = torch.Tensor(img)
    img = torch.unsqueeze(img, dim=0)  
    
    img = img.to(device)
    output = model(img)
    #output = torch.sum(output,dim=1)
    print(output.size())
    #_, predicted = torch.max(output, 1)
    return output

print(predict(model,'img/2222.jpg'))
# Out:
# torch.Size([1, 2])
# tensor([[0.6012, 0.3929]], device='cuda:0', grad_fn=<AddmmBackward>)
